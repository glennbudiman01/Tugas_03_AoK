# %% [markdown]
# <font color='chocolate'><h1>Analisis Data Survei Mengenai Keterampilan Menggunakan Internet dan E-Learning</font>
#
# Note : Gunakan https://nbviewer.jupyter.org Untuk Menampilkan Teks, karena terdapat beberapa teks yang tidak muncul jika dibuka dengan github

# %% [markdown]
# Pada kesempatan kali ini, kami akan melakukan analisa data survei yang telah dikumpulkan. data survei tersebut berisi data dari 501 orang yang berbeda - beda. Survei ini dibuat untuk mendapatkan data mengenai keterampilan dalam menggunakan internet dan E-Learning, data - data tersebut bisa berguna dalam pengembangan internet dan E-Learning

# %% [markdown]
# <font color='blue'> untuk pertanyaan - pertanyaan survei, kami menggunakan inisial seperti ini untuk memudahkan pengolahan data</font>
#
# <font color='blue'> Q1 = Adanya E-Learning membuat pelajar dapat mengakses materi pelajaran dimana saja, selama terhubung dengan jaringan Internet? </font>
#
#
# <font color='blue'>Q2 = Setelah menggunakan E-Learning, anda lebih cepat menangkap materi pembelajaran ?</font>
#
#
# <font color='blue'>Q3 = Dengan adanya E-Learning, materi - materi pembelajaran lebih mudah untuk dimengerti ?</font>
#
#
# <font color='blue'>Q4 = Terdapat banyak materi internet yang mengandung konten - konten negatif ?</font>
#
#
# <font color='blue'>Q5 = Apakah Biaya untuk mengakses internet di Indonesia mahal ?</font>
#
#
# <font color='blue'>Q6 = Dengan adanya E-learning, proses pembelajaran tidak memerlukan banyak biaya ?</font>
#
#
# <font color='blue'>Q7 = Apakah Ada materi yang tidak bisa disampaikan melalui E-learning. seperti praktek perakitan hardware ?</font>
#
#
# <font color='blue'>Q8 = Apakah akses internet di tempat asal sudah cepat ? </font>

# %% [markdown]
# Sebelum melakukan analisa data, kita harus mengubah data survei yang telah di dapat menjadi bentuk data angka agar bisa dilakukan analisis dengan benar tanpa adanya kesalahan

# %%
#Nilai jawaban dari tiap pertanyaan

# %% [markdown]
# Tabel di atas menunjukan nilai jawaban dari tiap pertanyaan yang dijawab oleh responden. untuk pertanyaan Q4 diberi nilai yang berkebalikan dengan pertanyaan lainnya karena Q4 tersebut berisi pertanyaan negatif.

# %% [markdown]
# # <font color='green'> Analisis Menggunakan Python </font>

# %% [markdown]
# <h3> 1. Menampilkan Data

# %%
#Tabel Head data

# %%
#Tabel Tail data

# %% [markdown]
# <font color='green'> 2 Tabel diatas ini merupakan hasil dari data survei yang telah diubah menjadi data angka. Karena di dalam jupyter notebook tidak bisa menampilkan terlalu banyak data, maka kami hanya menampilkan 5 data awal dan 5 data akhir </font>

# %% [markdown]
# <h3>2. Data Statistik

# %%
#Tabel Statistik Data

# %% [markdown]
# <font color='green'> Tabel diatas menunjukan data statisk dari 501 data yang telah diubah ke dalam angka. Count adalah jumlah data yaitu sebesar 501 data, mean adalah rata-rata dari nilai setiap pertanyaan. std adalah nilai standart deviasi setiap pertanyaan, 25% adalah nilai kuartil bawah dari setiap pertanyaan, 50% adalah nilai kuartil tengah (median) dari setiap pertanyaan, 75% adalah nilai kuartil atas dari setiap pertanyaan, min adalah nilai terendah setiap pertanyaan, dan max adalah nilai tertinggi setiap pertanyaan.  </font>
