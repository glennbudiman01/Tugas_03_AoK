# %%
import pandas as pd
import numpy as np

# %%
hasil_survey = pd.read_excel('D:survei.xlsx')
hasil_survey
# Out:
#                   Timestamp               Nama Lengkap  \
# 0   2020-03-18 01:06:51.318              Glenn Budiman
# 1   2020-03-18 01:30:17.218           Nafilia Sumolang
# 2   2020-03-18 01:33:00.840             Tania lamaluta
# 3   2020-03-18 01:35:12.723            Chindani Samate
# 4   2020-03-18 01:37:43.393                      randi
# ..                      ...                        ...
# 496 2020-04-07 20:50:24.000  Rizki Surya Kusuma Ahmady
# 497 2020-04-07 20:50:24.000         Edo Reynaldi Abasi
# 498 2020-04-07 20:58:26.000    Anisah Luthfi Fitriani
# 499 2020-04-07 21:57:25.000                     Latifa
# 500 2020-04-07 23:49:20.000            Jeshua Maloring
#
#                     Alamat Email  \
# 0       glennbudiman01@gmail.com
# 1     nafiliasumolan17@gmail.com
# 2          tanialmluta@gmail.com
# 3    chindani.samate06@gmail.con
# 4        randisalomons@gmail.com
# ..                           ...
# 496  rizkisuryakusumaa@gmail.com
# ...

# %%
print('Mean = ')
np.mean(hasil_survey)
# Out:
# Mean =
# Umur. (Isi angka saja)   18.489022
# dtype: float64

# %%
correlations = hasil_survey.corr()
correlations
# Out:
#                         Umur. (Isi angka saja)
# Umur. (Isi angka saja)                1.000000
